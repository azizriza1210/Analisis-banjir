# %%
import pandas as pd

# %%
df_2017 = pd.read_csv("data_banjir/data-banjir-jakarta-2017.csv")
# df_2018.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_2017 = pd.read_csv("data_banjir/data-banjir-jakarta-2017.csv")
#       2 # df_2018.tail()
#
# File c:\Program Files\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Program Files\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df_2019 = pd.read_csv("data-banjir-jakarta-2019.csv")
# df_2019.tail()
# Out:
#      Unnamed: 0 kota_administrasi         kecamatan            kelurahan  \
# 162          15     Jakarta Timur      KEC. MAKASAR      KEL. KEBON PALA
# 163          16     Jakarta Timur  KEC. KRAMAT JATI      KEL. BATU AMPAR
# 164          17     Jakarta Timur  KEC. KRAMAT JATI          KEL. CAWANG
# 165          18     Jakarta Timur   KEC. JATINEGARA  KEL. KAMPUNG MELAYU
# 166          19     Jakarta Timur   KEC. JATINEGARA     KEL. BIDARA CINA
#
#                    rw  jumlah_terdampak_rw  jumlah_terdampak_rt  \
# 162        06, 04, 05                    3                    3
# 163                 4                    1                    1
# 164                 3                    1                    2
# 165  04, 05, 07, 08,                     4                   25
# 166                 7                    1                   10
#
#      jumlah_terdampak_kk  jumlah_terdampak_jiwa ketinggian_air  \
# 162                    0                      0    30 - 50 cm
# ...

# %%
df_2020 = pd.read_csv("data-banjir-jakarta-2020.csv")
df_2020['tanggal_kejadian'] = df_2020['tanggal_kejadian'].str.lower()
# df_2020.tail(200)

# %%
tanggal_kejadian_kotor = df_2020['tanggal_kejadian'].to_numpy()
tanggal_kejadian_bersih = []
for i in range(len(tanggal_kejadian_kotor)) :
    kata = tanggal_kejadian_kotor[i].split(" ")
    for j in range(len(kata)) : 
        if j > (len(kata)-1) : 
            continue
        if (kata[j]) == "" : 
            kata.pop(j)
    for k in range(len(kata)) :
        if k > (len(kata)-1) : 
            continue 
        if kata[k] == kata[k-1] : 
            kata.pop(k)
            k -= 1
        elif kata[k] == kata[k-2] :
            kata.pop(k)
            k -= 1
    cek = " ".join(kata).split(" ")
    if len(cek[0]) == 10 : 
        benerin = cek[0].split("-")
        benerin = benerin[2]
        cek[0] = benerin 
    tanggal_kejadian_bersih.append(" ".join(cek))

df_2020['tanggal_kejadian'] = tanggal_kejadian_bersih    
df_2020.to_csv("data-banjir-jakarta-2020.csv")

# %% [markdown]
# Satuin Dataset Banjir

# %%
# Membaca file CSV
df_2018 = pd.read_csv('data-banjir-jakarta-2018.csv')
df_2019 = pd.read_csv('data-banjir-jakarta-2019.csv')
df_2020 = pd.read_csv('data-banjir-jakarta-2020.csv')

# Menggabungkan data dengan metode concat
merged_data = pd.concat([df_2018, df_2019, df_2020])
merged_data = merged_data.drop(merged_data.columns[0], axis=1)

# Menampilkan hasil penggabungan
# merged_data.to_csv("data-banjir-jakarta-3-tahun-terakhir.csv")

# %% [markdown]
# Bismillah

# %%
# Membaca file CSV
df_pasang_surut_2018 = pd.read_csv('pasang-surut/pasang_surut_2018.csv')
df_pasang_surut_2019 = pd.read_csv('pasang-surut/pasang_surut_2019.csv')
df_pasang_surut_2020 = pd.read_csv('pasang-surut/pasang_surut_2020.csv')

# Menggabungkan data dengan metode concat
merged_data = pd.concat([df_pasang_surut_2018, df_pasang_surut_2019, df_pasang_surut_2020])
merged_data = merged_data.drop(merged_data.columns[0], axis=1)

# Menampilkan hasil penggabungan
merged_data.to_csv("data-pasang-surut-3-tahun-terakhir.csv")
